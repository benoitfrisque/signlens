# %%
import pandas as pd

from signlens.params import *
from signlens.preprocessing.glossary import load_glossary
from signlens.preprocessing.data import load_video_list_json

# %%
glossary = load_glossary()

# %%
glossary
# Out:
#        sign
# 0      book
# 1     drink
# 2    before
# 3     chair
# 4        go
# ..      ...
# 233    wake
# 236    weus
# 247   yucky
# 248   zebra
# 249  zipper
#
# [250 rows x 1 columns]

# %%
videos = load_video_list_json()
videos.head()
# Out:
#        sign                   bbox  fps  frame_end  frame_start  instance_id  \
# 0  airplane  [605, 21, 1721, 1076]   25         -1            1           10
# 1     table    [374, 52, 810, 720]   25         -1            1           13
# 2       see     [85, 15, 230, 192]   25         -1            1            8
# 3       who     [165, 4, 472, 370]   25         -1            1           14
# 4       dog    [417, 61, 834, 720]   25         -1            1            7
#
#    signer_id        source  split  \
# 0          4    signschool  train
# 1         38      startasl  train
# 2         11  signingsavvy  train
# 3         88   aslsignbank  train
# 4         38      startasl  train
#
#                                                  url  variation_id video_id  \
# 0  https://signstock.blob.core.windows.net/signsc...             0    01726
# 1  https://s3-us-west-1.amazonaws.com/files.start...             0    56556
# 2  https://www.signingsavvy.com/signs/mp4/8/8396.mp4             0    50125
# 3  https://aslsignbank.haskins.yale.edu/dictionar...             0    66778
# 4  https://s3-us-west-1.amazonaws.com/files.start...             1    17086
#
#                                           video_path
# 0  /home/bfrisque/code/benoitfrisque/signlens/raw...
# 1  /home/bfrisque/code/benoitfrisque/signlens/raw...
# 2  /home/bfrisque/code/benoitfrisque/signlens/raw...
# 3  /home/bfrisque/code/benoitfrisque/signlens/raw...
# 4  /home/bfrisque/code/benoitfrisque/signlens/raw...

# %%
videos['sign_lower'] = videos['sign'].str.lower()

videos.head()
# Out:
#        sign                   bbox  fps  frame_end  frame_start  instance_id  \
# 0  airplane  [605, 21, 1721, 1076]   25         -1            1           10
# 1     table    [374, 52, 810, 720]   25         -1            1           13
# 2       see     [85, 15, 230, 192]   25         -1            1            8
# 3       who     [165, 4, 472, 370]   25         -1            1           14
# 4       dog    [417, 61, 834, 720]   25         -1            1            7
#
#    signer_id        source  split  \
# 0          4    signschool  train
# 1         38      startasl  train
# 2         11  signingsavvy  train
# 3         88   aslsignbank  train
# 4         38      startasl  train
#
#                                                  url  variation_id video_id  \
# 0  https://signstock.blob.core.windows.net/signsc...             0    01726
# 1  https://s3-us-west-1.amazonaws.com/files.start...             0    56556
# 2  https://www.signingsavvy.com/signs/mp4/8/8396.mp4             0    50125
# 3  https://aslsignbank.haskins.yale.edu/dictionar...             0    66778
# 4  https://s3-us-west-1.amazonaws.com/files.start...             1    17086
#
#                                           video_path sign_lower
# 0  /home/bfrisque/code/benoitfrisque/signlens/raw...   airplane
# 1  /home/bfrisque/code/benoitfrisque/signlens/raw...      table
# 2  /home/bfrisque/code/benoitfrisque/signlens/raw...        see
# 3  /home/bfrisque/code/benoitfrisque/signlens/raw...        who
# 4  /home/bfrisque/code/benoitfrisque/signlens/raw...        dog
